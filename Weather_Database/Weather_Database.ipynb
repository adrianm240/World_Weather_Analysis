# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]        
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | prince rupert
# Processing Record 2 of Set 1 | puerto ayora
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | isla vista
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | alghero
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | leningradskiy
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | carnarvon
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | ilulissat
# Processing Record 18 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | vanimo
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | tura
# Processing Record 26 of Set 1 | carrollton
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 1 | urumqi
# Processing Record 30 of Set 1 | saint george
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | san miguel
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | san joaquin
# Processing Record 37 of Set 1 | mangrol
# Processing Record 38 of Set 1 | dorchester
# Processing Record 39 of Set 1 | tambo
# Processing Record 40 of Set 1 | maceio
# Processing Record 41 of Set 1 | alugan
# Processing Record 42 of Set 1 | kavaratti
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | hualmay
# Processing Record 45 of Set 1 | ngama
# Processing Record 46 of Set 1 | sur
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | diamantino
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 1 of Set 2 | oistins
# Processing Record 2 of Set 2 | ancud
# Processing Record 3 of Set 2 | seoul
# Processing Record 4 of Set 2 | itoman
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 2 | barda
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | boa vista
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | san rafael
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | tabou
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | jibuti
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | brae
# Processing Record 22 of Set 2 | sorong
# Processing Record 23 of Set 2 | santona
# Processing Record 24 of Set 2 | mar del plata
# Processing Record 25 of Set 2 | nanortalik
# Processing Record 26 of Set 2 | dum duma
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | komsomolskiy
# Processing Record 29 of Set 2 | schleswig
# Processing Record 30 of Set 2 | monster
# Processing Record 31 of Set 2 | nikita
# Processing Record 32 of Set 2 | ushuaia
# Processing Record 33 of Set 2 | sinnamary
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | jasidih
# Processing Record 37 of Set 2 | zhigansk
# Processing Record 38 of Set 2 | norwich
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | paita
# Processing Record 41 of Set 2 | dunedin
# Processing Record 42 of Set 2 | galesburg
# Processing Record 43 of Set 2 | tuktoyaktuk
# Processing Record 44 of Set 2 | namtsy
# Processing Record 45 of Set 2 | kulhudhuffushi
# Processing Record 46 of Set 2 | mayo
# Processing Record 47 of Set 2 | sorland
# Processing Record 48 of Set 2 | bay roberts
# Processing Record 49 of Set 2 | huarmey
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | toamasina
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | hobart
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | palmer
# Processing Record 9 of Set 3 | sao joaquim
# Processing Record 10 of Set 3 | ayagoz
# Processing Record 11 of Set 3 | khuzhir
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | noumea
# Processing Record 14 of Set 3 | haines junction
# Processing Record 15 of Set 3 | tomatlan
# Processing Record 16 of Set 3 | aberystwyth
# Processing Record 17 of Set 3 | mana
# Processing Record 18 of Set 3 | haimen
# Processing Record 19 of Set 3 | ada
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | pierre
# Processing Record 22 of Set 3 | ust-ishim
# Processing Record 23 of Set 3 | reconquista
# Processing Record 24 of Set 3 | dikson
# Processing Record 25 of Set 3 | charters towers
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | kahului
# Processing Record 28 of Set 3 | skegness
# Processing Record 29 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 3 | pakokku
# Processing Record 31 of Set 3 | clyde river
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | sistranda
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | dharchula
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | khatanga
# Processing Record 38 of Set 3 | hilo
# Processing Record 39 of Set 3 | nemuro
# Processing Record 40 of Set 3 | arman
# Processing Record 41 of Set 3 | bocaranga
# City not found. Skipping...
# Processing Record 42 of Set 3 | rota
# Processing Record 43 of Set 3 | santa isabel do rio negro
# Processing Record 44 of Set 3 | chapais
# Processing Record 45 of Set 3 | kasempa
# Processing Record 46 of Set 3 | bathsheba
# Processing Record 47 of Set 3 | mitchell
# Processing Record 48 of Set 3 | lake havasu city
# Processing Record 49 of Set 3 | la ronge
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | yenagoa
# Processing Record 2 of Set 4 | alihe
# Processing Record 3 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 4 | andahuaylas
# Processing Record 5 of Set 4 | sakakah
# Processing Record 6 of Set 4 | kyakhta
# Processing Record 7 of Set 4 | tiksi
# Processing Record 8 of Set 4 | cayenne
# Processing Record 9 of Set 4 | tieling
# Processing Record 10 of Set 4 | lata
# Processing Record 11 of Set 4 | east london
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | coihaique
# Processing Record 14 of Set 4 | esperance
# Processing Record 15 of Set 4 | yanam
# Processing Record 16 of Set 4 | tupik
# Processing Record 17 of Set 4 | roald
# Processing Record 18 of Set 4 | benicarlo
# Processing Record 19 of Set 4 | cape town
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | zhezkazgan
# Processing Record 22 of Set 4 | izhmorskiy
# Processing Record 23 of Set 4 | laguna
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | lompoc
# Processing Record 26 of Set 4 | ulaanbaatar
# Processing Record 27 of Set 4 | quatre cocos
# Processing Record 28 of Set 4 | nipawin
# Processing Record 29 of Set 4 | anadyr
# Processing Record 30 of Set 4 | kijang
# Processing Record 31 of Set 4 | touros
# Processing Record 32 of Set 4 | nchelenge
# Processing Record 33 of Set 4 | irtyshskiy
# Processing Record 34 of Set 4 | mitsamiouli
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | malaut
# Processing Record 37 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 4 | arkhara
# Processing Record 39 of Set 4 | te anau
# Processing Record 40 of Set 4 | rio gallegos
# Processing Record 41 of Set 4 | turukhansk
# Processing Record 42 of Set 4 | asau
# Processing Record 43 of Set 4 | colares
# Processing Record 44 of Set 4 | rancho palos verdes
# Processing Record 45 of Set 4 | pisco
# Processing Record 46 of Set 4 | ibra
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | khani
# Processing Record 49 of Set 4 | ukiah
# Processing Record 50 of Set 4 | nanning
# Processing Record 1 of Set 5 | bonavista
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 5 | kalabo
# Processing Record 5 of Set 5 | rawson
# Processing Record 6 of Set 5 | inuvik
# Processing Record 7 of Set 5 | el limon
# Processing Record 8 of Set 5 | buenos aires
# Processing Record 9 of Set 5 | tank
# Processing Record 10 of Set 5 | naze
# Processing Record 11 of Set 5 | mahebourg
# Processing Record 12 of Set 5 | samarai
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 5 | cherskiy
# Processing Record 16 of Set 5 | ust-tsilma
# Processing Record 17 of Set 5 | sibolga
# Processing Record 18 of Set 5 | andra
# Processing Record 19 of Set 5 | buala
# Processing Record 20 of Set 5 | longyan
# Processing Record 21 of Set 5 | port augusta
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | la gaulette
# City not found. Skipping...
# Processing Record 24 of Set 5 | narsaq
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | lloydminster
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 5 | daru
# Processing Record 29 of Set 5 | tottori
# Processing Record 30 of Set 5 | alice town
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | barletta
# Processing Record 33 of Set 5 | esna
# Processing Record 34 of Set 5 | riyadh
# Processing Record 35 of Set 5 | sing buri
# Processing Record 36 of Set 5 | guymon
# Processing Record 37 of Set 5 | port pirie
# Processing Record 38 of Set 5 | lorengau
# Processing Record 39 of Set 5 | walvis bay
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | alofi
# Processing Record 42 of Set 5 | gizo
# Processing Record 43 of Set 5 | kaeo
# Processing Record 44 of Set 5 | suicheng
# Processing Record 45 of Set 5 | constitucion
# Processing Record 46 of Set 5 | saurimo
# Processing Record 47 of Set 5 | genc
# Processing Record 48 of Set 5 | pervomayskoye
# Processing Record 49 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 50 of Set 5 | porto nacional
# Processing Record 1 of Set 6 | turochak
# Processing Record 2 of Set 6 | eten
# Processing Record 3 of Set 6 | campina verde
# Processing Record 4 of Set 6 | tandalti
# Processing Record 5 of Set 6 | dogondoutchi
# Processing Record 6 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 6 | muroto
# Processing Record 8 of Set 6 | san jose
# Processing Record 9 of Set 6 | mahon
# Processing Record 10 of Set 6 | toma
# Processing Record 11 of Set 6 | sungaipenuh
# Processing Record 12 of Set 6 | erenhot
# Processing Record 13 of Set 6 | primero de enero
# Processing Record 14 of Set 6 | skjervoy
# Processing Record 15 of Set 6 | marmaron
# City not found. Skipping...
# Processing Record 16 of Set 6 | majene
# Processing Record 17 of Set 6 | jalu
# Processing Record 18 of Set 6 | cidreira
# Processing Record 19 of Set 6 | ilanskiy
# Processing Record 20 of Set 6 | chuy
# Processing Record 21 of Set 6 | kruisfontein
# Processing Record 22 of Set 6 | catemaco
# Processing Record 23 of Set 6 | srednekolymsk
# Processing Record 24 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 6 | impfondo
# Processing Record 26 of Set 6 | isangel
# Processing Record 27 of Set 6 | aitape
# Processing Record 28 of Set 6 | floro
# Processing Record 29 of Set 6 | langsa
# Processing Record 30 of Set 6 | saskatoon
# Processing Record 31 of Set 6 | lavrentiya
# Processing Record 32 of Set 6 | palu
# Processing Record 33 of Set 6 | san jose de guanipa
# Processing Record 34 of Set 6 | bull savanna
# Processing Record 35 of Set 6 | afua
# Processing Record 36 of Set 6 | port blair
# Processing Record 37 of Set 6 | gremyachye
# City not found. Skipping...
# Processing Record 38 of Set 6 | vardo
# Processing Record 39 of Set 6 | victoria
# Processing Record 40 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 6 | vieste
# Processing Record 42 of Set 6 | shiraoi
# Processing Record 43 of Set 6 | goure
# Processing Record 44 of Set 6 | leh
# Processing Record 45 of Set 6 | klaksvik
# Processing Record 46 of Set 6 | malpura
# Processing Record 47 of Set 6 | fortuna
# Processing Record 48 of Set 6 | sanchez
# Processing Record 49 of Set 6 | oranjemund
# Processing Record 50 of Set 6 | san carlos de bariloche
# Processing Record 1 of Set 7 | paamiut
# Processing Record 2 of Set 7 | barra patuca
# Processing Record 3 of Set 7 | wenling
# Processing Record 4 of Set 7 | teruel
# Processing Record 5 of Set 7 | moranbah
# Processing Record 6 of Set 7 | souillac
# Processing Record 7 of Set 7 | abu samrah
# Processing Record 8 of Set 7 | linhares
# Processing Record 9 of Set 7 | male
# Processing Record 10 of Set 7 | dyersburg
# Processing Record 11 of Set 7 | ostersund
# Processing Record 12 of Set 7 | camacha
# Processing Record 13 of Set 7 | hegang
# Processing Record 14 of Set 7 | mehamn
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | virginia beach
# Processing Record 17 of Set 7 | chhabra
# Processing Record 18 of Set 7 | oksovskiy
# Processing Record 19 of Set 7 | kaduy
# Processing Record 20 of Set 7 | tukrah
# Processing Record 21 of Set 7 | ngaoundere
# Processing Record 22 of Set 7 | kaseda
# Processing Record 23 of Set 7 | kulim
# Processing Record 24 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 7 | silyanah
# City not found. Skipping...
# Processing Record 26 of Set 7 | waw
# Processing Record 27 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 28 of Set 7 | carauari
# Processing Record 29 of Set 7 | jasper
# Processing Record 30 of Set 7 | arica
# Processing Record 31 of Set 7 | aguadas
# Processing Record 32 of Set 7 | mugumu
# Processing Record 33 of Set 7 | tarakan
# Processing Record 34 of Set 7 | biak
# Processing Record 35 of Set 7 | ambilobe
# Processing Record 36 of Set 7 | shimoda
# Processing Record 37 of Set 7 | nhulunbuy
# Processing Record 38 of Set 7 | thunder bay
# Processing Record 39 of Set 7 | rocha
# Processing Record 40 of Set 7 | wanning
# Processing Record 41 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 7 | newport
# Processing Record 43 of Set 7 | itarema
# Processing Record 44 of Set 7 | viedma
# Processing Record 45 of Set 7 | ambon
# Processing Record 46 of Set 7 | grand gaube
# Processing Record 47 of Set 7 | birao
# Processing Record 48 of Set 7 | baruun-urt
# Processing Record 49 of Set 7 | ambanja
# Processing Record 50 of Set 7 | kiama
# Processing Record 1 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 8 | yako
# Processing Record 3 of Set 8 | edd
# Processing Record 4 of Set 8 | cravo norte
# Processing Record 5 of Set 8 | nizhniy kuranakh
# Processing Record 6 of Set 8 | takoradi
# Processing Record 7 of Set 8 | yar-sale
# Processing Record 8 of Set 8 | lishu
# Processing Record 9 of Set 8 | pemberton
# Processing Record 10 of Set 8 | aklavik
# Processing Record 11 of Set 8 | tiznit
# Processing Record 12 of Set 8 | santa maria
# Processing Record 13 of Set 8 | kangaatsiaq
# Processing Record 14 of Set 8 | meulaboh
# Processing Record 15 of Set 8 | jiangyin
# Processing Record 16 of Set 8 | san ignacio
# Processing Record 17 of Set 8 | booue
# Processing Record 18 of Set 8 | hasaki
# Processing Record 19 of Set 8 | dossor
# Processing Record 20 of Set 8 | muros
# Processing Record 21 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 8 | podgornoye
# Processing Record 23 of Set 8 | port keats
# Processing Record 24 of Set 8 | ishigaki
# Processing Record 25 of Set 8 | carbonia
# Processing Record 26 of Set 8 | ruteng
# Processing Record 27 of Set 8 | san cristobal
# Processing Record 28 of Set 8 | ambato
# Processing Record 29 of Set 8 | rochefort
# Processing Record 30 of Set 8 | harlau
# Processing Record 31 of Set 8 | necochea
# Processing Record 32 of Set 8 | hami
# Processing Record 33 of Set 8 | kiunga
# Processing Record 34 of Set 8 | kavieng
# Processing Record 35 of Set 8 | high level
# Processing Record 36 of Set 8 | omboue
# Processing Record 37 of Set 8 | tasiilaq
# Processing Record 38 of Set 8 | chenghai
# Processing Record 39 of Set 8 | shimonoseki
# Processing Record 40 of Set 8 | honningsvag
# Processing Record 41 of Set 8 | salekhard
# Processing Record 42 of Set 8 | duncan
# Processing Record 43 of Set 8 | talcahuano
# Processing Record 44 of Set 8 | staryy nadym
# Processing Record 45 of Set 8 | aden
# Processing Record 46 of Set 8 | odweyne
# Processing Record 47 of Set 8 | cam ranh
# Processing Record 48 of Set 8 | udarnyy
# Processing Record 49 of Set 8 | torbay
# Processing Record 50 of Set 8 | touba
# Processing Record 1 of Set 9 | birsk
# Processing Record 2 of Set 9 | uyuni
# Processing Record 3 of Set 9 | xinyang
# Processing Record 4 of Set 9 | veraval
# Processing Record 5 of Set 9 | wawa
# Processing Record 6 of Set 9 | mount gambier
# Processing Record 7 of Set 9 | shache
# Processing Record 8 of Set 9 | marsh harbour
# Processing Record 9 of Set 9 | lazaro cardenas
# Processing Record 10 of Set 9 | dalbandin
# Processing Record 11 of Set 9 | gimli
# Processing Record 12 of Set 9 | mount isa
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | tavares
# Processing Record 15 of Set 9 | husavik
# Processing Record 16 of Set 9 | tuatapere
# Processing Record 17 of Set 9 | ostrovnoy
# Processing Record 18 of Set 9 | lasa
# Processing Record 19 of Set 9 | mildura
# Processing Record 20 of Set 9 | sola
# Processing Record 21 of Set 9 | kysyl-syr
# Processing Record 22 of Set 9 | baker city
# Processing Record 23 of Set 9 | coahuayana
# Processing Record 24 of Set 9 | bone
# Processing Record 25 of Set 9 | novyy urgal
# Processing Record 26 of Set 9 | milkovo
# Processing Record 27 of Set 9 | thanh hoa
# Processing Record 28 of Set 9 | traverse city
# Processing Record 29 of Set 9 | nehe
# Processing Record 30 of Set 9 | arlit
# Processing Record 31 of Set 9 | banes
# Processing Record 32 of Set 9 | la primavera
# Processing Record 33 of Set 9 | ntchisi
# Processing Record 34 of Set 9 | zykovo
# Processing Record 35 of Set 9 | sobolevo
# Processing Record 36 of Set 9 | salalah
# Processing Record 37 of Set 9 | nyurba
# Processing Record 38 of Set 9 | tarragona
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | kloulklubed
# Processing Record 41 of Set 9 | hachioji
# Processing Record 42 of Set 9 | lufilufi
# Processing Record 43 of Set 9 | labuhan
# Processing Record 44 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 45 of Set 9 | longyearbyen
# Processing Record 46 of Set 9 | ballina
# Processing Record 47 of Set 9 | les cayes
# Processing Record 48 of Set 9 | salamiyah
# Processing Record 49 of Set 9 | gewane
# Processing Record 50 of Set 9 | darnah
# Processing Record 1 of Set 10 | grindavik
# Processing Record 2 of Set 10 | artvin
# Processing Record 3 of Set 10 | beloha
# Processing Record 4 of Set 10 | malpe
# Processing Record 5 of Set 10 | mitu
# Processing Record 6 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | lilongwe
# Processing Record 9 of Set 10 | maua
# Processing Record 10 of Set 10 | aswan
# Processing Record 11 of Set 10 | guerrero negro
# Processing Record 12 of Set 10 | namatanai
# Processing Record 13 of Set 10 | jardim
# Processing Record 14 of Set 10 | coquimbo
# Processing Record 15 of Set 10 | fairbanks
# Processing Record 16 of Set 10 | bulawayo
# Processing Record 17 of Set 10 | weyburn
# Processing Record 18 of Set 10 | trat
# Processing Record 19 of Set 10 | saint-joseph
# Processing Record 20 of Set 10 | chunskiy
# Processing Record 21 of Set 10 | vestmannaeyjar
# Processing Record 22 of Set 10 | san ramon
# Processing Record 23 of Set 10 | cururupu
# Processing Record 24 of Set 10 | cuajinicuilapa
# Processing Record 25 of Set 10 | baghdad
# Processing Record 26 of Set 10 | comodoro rivadavia
# Processing Record 27 of Set 10 | san carlos
# Processing Record 28 of Set 10 | banjarmasin
# Processing Record 29 of Set 10 | kindu
# Processing Record 30 of Set 10 | dongzhen
# Processing Record 31 of Set 10 | ucluelet
# Processing Record 32 of Set 10 | nanchong
# Processing Record 33 of Set 10 | epe
# Processing Record 34 of Set 10 | tessalit
# Processing Record 35 of Set 10 | rafsanjan
# Processing Record 36 of Set 10 | albanel
# Processing Record 37 of Set 10 | balabac
# Processing Record 38 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 39 of Set 10 | namibe
# Processing Record 40 of Set 10 | bonham
# Processing Record 41 of Set 10 | kidal
# Processing Record 42 of Set 10 | vila velha
# Processing Record 43 of Set 10 | sergeyevka
# Processing Record 44 of Set 10 | roebourne
# Processing Record 45 of Set 10 | jurado
# Processing Record 46 of Set 10 | saint-denis
# Processing Record 47 of Set 10 | osa
# Processing Record 48 of Set 10 | otane
# Processing Record 49 of Set 10 | ouadda
# Processing Record 50 of Set 10 | dingle
# Processing Record 1 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 11 | miles city
# Processing Record 3 of Set 11 | muncar
# Processing Record 4 of Set 11 | talnakh
# Processing Record 5 of Set 11 | smoky lake
# Processing Record 6 of Set 11 | dwarka
# Processing Record 7 of Set 11 | amapa
# Processing Record 8 of Set 11 | severo-kurilsk
# Processing Record 9 of Set 11 | vejen
# Processing Record 10 of Set 11 | aleksandrovskiy zavod
# Processing Record 11 of Set 11 | puerto carreno
# Processing Record 12 of Set 11 | jatara
# Processing Record 13 of Set 11 | ossora
# Processing Record 14 of Set 11 | goundam
# Processing Record 15 of Set 11 | gannavaram
# Processing Record 16 of Set 11 | cabo san lucas
# Processing Record 17 of Set 11 | yurga
# Processing Record 18 of Set 11 | zhanaozen
# Processing Record 19 of Set 11 | mashivka
# Processing Record 20 of Set 11 | thompson
# Processing Record 21 of Set 11 | mutsu
# Processing Record 22 of Set 11 | yerbogachen
# Processing Record 23 of Set 11 | yumen
# Processing Record 24 of Set 11 | cuamba
# Processing Record 25 of Set 11 | rafaela
# Processing Record 26 of Set 11 | stephenville
# Processing Record 27 of Set 11 | sabang
# Processing Record 28 of Set 11 | muleba
# Processing Record 29 of Set 11 | bonthe
# Processing Record 30 of Set 11 | altamira
# Processing Record 31 of Set 11 | northam
# Processing Record 32 of Set 11 | mercedes
# Processing Record 33 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 11 | uk
# City not found. Skipping...
# Processing Record 35 of Set 11 | vorokhta
# Processing Record 36 of Set 11 | port hardy
# Processing Record 37 of Set 11 | oussouye
# Processing Record 38 of Set 11 | yeppoon
# Processing Record 39 of Set 11 | cortez
# Processing Record 40 of Set 11 | mogadishu
# Processing Record 41 of Set 11 | pemangkat
# Processing Record 42 of Set 11 | matamoros
# Processing Record 43 of Set 11 | biltine
# Processing Record 44 of Set 11 | mafeteng
# Processing Record 45 of Set 11 | pacific grove
# Processing Record 46 of Set 11 | visnes
# Processing Record 47 of Set 11 | sesheke
# Processing Record 48 of Set 11 | zhicheng
# Processing Record 49 of Set 11 | kismayo
# Processing Record 50 of Set 11 | moron
# Processing Record 1 of Set 12 | hatta
# Processing Record 2 of Set 12 | aksarka
# Processing Record 3 of Set 12 | clermont
# Processing Record 4 of Set 12 | kitami
# Processing Record 5 of Set 12 | rosarito
# Processing Record 6 of Set 12 | chor
# Processing Record 7 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record 9 of Set 12 | mathbaria
# Processing Record 10 of Set 12 | lanciano
# Processing Record 11 of Set 12 | kirkwall
# Processing Record 12 of Set 12 | chardara
# Processing Record 13 of Set 12 | miri
# Processing Record 14 of Set 12 | griffith
# Processing Record 15 of Set 12 | la union
# Processing Record 16 of Set 12 | dalaba
# Processing Record 17 of Set 12 | kutulik
# Processing Record 18 of Set 12 | porosozero
# Processing Record 19 of Set 12 | maham
# Processing Record 20 of Set 12 | kropotkin
# Processing Record 21 of Set 12 | oparino
# Processing Record 22 of Set 12 | sioux lookout
# Processing Record 23 of Set 12 | winnemucca
# Processing Record 24 of Set 12 | at-bashi
# Processing Record 25 of Set 12 | juegang
# Processing Record 26 of Set 12 | adrar
# Processing Record 27 of Set 12 | aberchirder
# Processing Record 28 of Set 12 | awbari
# Processing Record 29 of Set 12 | mweka
# Processing Record 30 of Set 12 | podporozhye
# Processing Record 31 of Set 12 | sarangani
# Processing Record 32 of Set 12 | fort nelson
# Processing Record 33 of Set 12 | karpogory
# Processing Record 34 of Set 12 | sawtell
# Processing Record 35 of Set 12 | chinsali
# Processing Record 36 of Set 12 | nouadhibou
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | kokstad
# Processing Record 39 of Set 12 | gravdal
# Processing Record 40 of Set 12 | deputatskiy
# Processing Record 41 of Set 12 | jijiga
# Processing Record 42 of Set 12 | umm lajj
# Processing Record 43 of Set 12 | sakaiminato
# Processing Record 44 of Set 12 | usinsk
# Processing Record 45 of Set 12 | ust-kuyga
# Processing Record 46 of Set 12 | gornopravdinsk
# Processing Record 47 of Set 12 | mapiripan
# Processing Record 48 of Set 12 | twentynine palms
# Processing Record 49 of Set 12 | whitianga
# Processing Record 50 of Set 12 | kargala
# Processing Record 1 of Set 13 | korla
# Processing Record 2 of Set 13 | rupert
# Processing Record 3 of Set 13 | mamou
# Processing Record 4 of Set 13 | eureka
# Processing Record 5 of Set 13 | beauvais
# Processing Record 6 of Set 13 | miandoab
# Processing Record 7 of Set 13 | freeport
# Processing Record 8 of Set 13 | keti bandar
# Processing Record 9 of Set 13 | jumla
# Processing Record 10 of Set 13 | maiduguri
# Processing Record 11 of Set 13 | manicore
# Processing Record 12 of Set 13 | azul
# Processing Record 13 of Set 13 | banda aceh
# Processing Record 14 of Set 13 | bulgan
# Processing Record 15 of Set 13 | rabo de peixe
# Processing Record 16 of Set 13 | inirida
# Processing Record 17 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 18 of Set 13 | gela
# Processing Record 19 of Set 13 | miraflores
# Processing Record 20 of Set 13 | portknockie
# Processing Record 21 of Set 13 | caravelas
# Processing Record 22 of Set 13 | la macarena
# Processing Record 23 of Set 13 | tautira
# Processing Record 24 of Set 13 | kristiinankaupunki
# Processing Record 25 of Set 13 | okakarara
# Processing Record 26 of Set 13 | sirpur
# Processing Record 27 of Set 13 | matagami
# Processing Record 28 of Set 13 | puerto madryn
# Processing Record 29 of Set 13 | nelson bay
# Processing Record 30 of Set 13 | sabaudia
# Processing Record 31 of Set 13 | abaetetuba
# Processing Record 32 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 33 of Set 13 | karaton
# Processing Record 34 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 13 | westport
# Processing Record 36 of Set 13 | parker
# Processing Record 37 of Set 13 | bibbiena
# Processing Record 38 of Set 13 | thoen
# Processing Record 39 of Set 13 | waynesville
# Processing Record 40 of Set 13 | vilhena
# Processing Record 41 of Set 13 | lagoa
# Processing Record 42 of Set 13 | binzhou
# Processing Record 43 of Set 13 | champerico
# Processing Record 44 of Set 13 | kuvandyk
# Processing Record 45 of Set 13 | praya
# Processing Record 46 of Set 13 | rosario
# Processing Record 47 of Set 13 | makakilo city
# Processing Record 48 of Set 13 | grand-lahou
# Processing Record 49 of Set 13 | padang
# Processing Record 50 of Set 13 | price
# Processing Record 1 of Set 14 | vila
# Processing Record 2 of Set 14 | erzurum
# Processing Record 3 of Set 14 | ampanihy
# Processing Record 4 of Set 14 | san quintin
# Processing Record 5 of Set 14 | narbonne
# Processing Record 6 of Set 14 | shieli
# Processing Record 7 of Set 14 | davila
# Processing Record 8 of Set 14 | los llanos de aridane
# Processing Record 9 of Set 14 | nioro
# Processing Record 10 of Set 14 | ranau
# Processing Record 11 of Set 14 | santiago
# Processing Record 12 of Set 14 | sisimiut
# Processing Record 13 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 14 | kaman
# Processing Record 15 of Set 14 | phanom thuan
# Processing Record 16 of Set 14 | phan thiet
# Processing Record 17 of Set 14 | lakshmipur
# Processing Record 18 of Set 14 | huicungo
# Processing Record 19 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 20 of Set 14 | pustomyty
# Processing Record 21 of Set 14 | boljarovo
# City not found. Skipping...
# Processing Record 22 of Set 14 | eenhana
# Processing Record 23 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 14 | energetik
# Processing Record 25 of Set 14 | puerto narino
# Processing Record 26 of Set 14 | cabedelo
# Processing Record 27 of Set 14 | soto la marina
# Processing Record 28 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 29 of Set 14 | khuzdar
# Processing Record 30 of Set 14 | puerto maldonado
# Processing Record 31 of Set 14 | bonoua
# Processing Record 32 of Set 14 | praia
# Processing Record 33 of Set 14 | excelsior springs
# Processing Record 34 of Set 14 | saryg-sep
# Processing Record 35 of Set 14 | vilyuysk
# Processing Record 36 of Set 14 | riorges
# Processing Record 37 of Set 14 | pedra
# Processing Record 38 of Set 14 | yalvac
# Processing Record 39 of Set 14 | huilong
# Processing Record 40 of Set 14 | jackson
# Processing Record 41 of Set 14 | jacmel
# Processing Record 42 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 43 of Set 14 | sladkovo
# Processing Record 44 of Set 14 | osypenko
# Processing Record 45 of Set 14 | tateyama
# Processing Record 46 of Set 14 | abeche
# Processing Record 47 of Set 14 | goya
# Processing Record 48 of Set 14 | axim
# Processing Record 49 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 50 of Set 14 | rusne
# Processing Record 1 of Set 15 | sao jose da coroa grande
# Processing Record 2 of Set 15 | alice springs
# Processing Record 3 of Set 15 | banepa
# Processing Record 4 of Set 15 | puerto escondido
# Processing Record 5 of Set 15 | masty
# Processing Record 6 of Set 15 | robinson
# Processing Record 7 of Set 15 | general roca
# Processing Record 8 of Set 15 | acapulco
# Processing Record 9 of Set 15 | kurilsk
# Processing Record 10 of Set 15 | grafton
# Processing Record 11 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 15 | galesong
# Processing Record 13 of Set 15 | sao joao da barra
# Processing Record 14 of Set 15 | mazagao
# Processing Record 15 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 15 | masterton
# Processing Record 17 of Set 15 | apiai
# Processing Record 18 of Set 15 | zemio
# Processing Record 19 of Set 15 | whitehorse
# Processing Record 20 of Set 15 | southbridge
# Processing Record 21 of Set 15 | burns lake
# Processing Record 22 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 15 | pedernales
# Processing Record 24 of Set 15 | pochutla
# Processing Record 25 of Set 15 | cabras
# Processing Record 26 of Set 15 | celestun
# Processing Record 27 of Set 15 | rock sound
# Processing Record 28 of Set 15 | fort smith
# Processing Record 29 of Set 15 | sabya
# Processing Record 30 of Set 15 | rassvet
# Processing Record 31 of Set 15 | zalantun
# Processing Record 32 of Set 15 | tongren
# Processing Record 33 of Set 15 | kazerun
# Processing Record 34 of Set 15 | xiongyue
# Processing Record 35 of Set 15 | pilar
# Processing Record 36 of Set 15 | wamba
# Processing Record 37 of Set 15 | abnub
# Processing Record 38 of Set 15 | the valley
# Processing Record 39 of Set 15 | scarborough
# Processing Record 40 of Set 15 | antalaha
# Processing Record 41 of Set 15 | aflao
# Processing Record 42 of Set 15 | danjiangkou
# Processing Record 43 of Set 15 | tambul
# City not found. Skipping...
# Processing Record 44 of Set 15 | indiaroba
# Processing Record 45 of Set 15 | burnie
# Processing Record 46 of Set 15 | rovaniemi
# Processing Record 47 of Set 15 | omsukchan
# Processing Record 48 of Set 15 | atar
# Processing Record 49 of Set 15 | hamina
# Processing Record 50 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 1 of Set 16 | iberia
# Processing Record 2 of Set 16 | sedalia
# Processing Record 3 of Set 16 | burlatskoye
# Processing Record 4 of Set 16 | tooele
# Processing Record 5 of Set 16 | grand forks
# Processing Record 6 of Set 16 | jiuquan
# Processing Record 7 of Set 16 | praia da vitoria
# Processing Record 8 of Set 16 | dzilam gonzalez
# Processing Record 9 of Set 16 | thinadhoo
# Processing Record 10 of Set 16 | ahipara
# Processing Record 11 of Set 16 | katherine
# Processing Record 12 of Set 16 | besancon
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Prince Rupert      CA  54.3161 -130.3201     53.69       100         100
# 1   Puerto Ayora      EC  -0.7393  -90.3518     69.55        95          99
# 2       Luderitz      NA -26.6481   15.1594     69.24        27           0
# 3          Bluff      NZ -46.6000  168.3333     47.26        75          95
# 4     Isla Vista      US  34.4133 -119.8610     92.37        29           1
# 5           Lebu      CL -37.6167  -73.6500     44.26        82          26
# 6        Qaanaaq      GL  77.4840  -69.3632     51.30        60          76
# 7      Upernavik      GL  72.7868  -56.1549     47.48        64          13
# 8        Alghero      IT  40.5589    8.3181     66.29       100           0
# 9    Yellowknife      CA  62.4560 -114.3525     64.09        54          56
#
#    Wind Speed Current Description
# 0        3.44       moderate rain
# 1        8.99     overcast clouds
# 2        8.77           clear sky
# 3       22.93     overcast clouds
# 4        4.14           clear sky
# 5        2.64    scattered clouds
# 6        8.30       broken clouds
# 7        2.62          few clouds
# 8        1.14           clear sky
# 9        9.42       broken clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
